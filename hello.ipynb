# %%
print("Hello from VSCode to GitHub and Colab!")
# Out:
# Hello from VSCode to GitHub and Colab!

# %%
print("Hello from Colab to VSCode and Github!")
# Out:
# Hello from Colab to VSCode and Github!
